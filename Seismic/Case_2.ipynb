# %%
import matplotlib.pyplot as plt
import numpy as np
from typing import Optional
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam
import tqdm
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#print('Current cuda device: ',torch.cuda.get_device_name(0))

# %%
# !pip install gstools
import gstools as gs
# Out:
# Collecting gstools
#   Downloading gstools-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting emcee>=3.0.0 (from gstools)
#   Downloading emcee-3.1.6-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting hankel>=1.0.0 (from gstools)
#   Downloading hankel-1.2.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting meshio>=5.1.0 (from gstools)
#   Downloading meshio-5.3.5-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from gstools) (1.26.4)
# Collecting pyevtk>=1.1.1 (from gstools)
#   Downloading pyevtk-1.6.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from gstools) (1.13.1)
# Requirement already satisfied: mpmath>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from hankel>=1.0.0->gstools) (1.3.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from meshio>=5.1.0->gstools) (13.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->meshio>=5.1.0->gstools) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->meshio>=5.1.0->gstools) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->meshio>=5.1.0->gstools) (0.1.2)
# Downloading gstools-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 37.4 MB/s eta 0:00:00
# Downloading emcee-3.1.6-py2.py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 kB 3.8 MB/s eta 0:00:00
# Downloading hankel-1.2.2-py3-none-any.whl (12 kB)
# Downloading meshio-5.3.5-py3-none-any.whl (166 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.2/166.2 kB 12.6 MB/s eta 0:00:00
# Downloading pyevtk-1.6.0-py3-none-any.whl (20 kB)
# Installing collected packages: pyevtk, emcee, hankel, meshio, gstools
# Successfully installed emcee-3.1.6 gstools-1.6.1 hankel-1.2.2 meshio-5.3.5 pyevtk-1.6.0

# %%
# Codes for the forward tomography problem
class tomography(nn.Module):

    def __init__(self, zs, ze, x, z):
      # rays start at (x[0], zs[i]) and end at (x[-1], ze[j])

        super().__init__()

        self.zs = zs
        self.ze = ze
        self.z  = z
        self.x  = x
        self.A = self.get_tomo_matrix(zs, ze, x, z)


    def get_ray(self, zs, ze, x, z):

        n = x.numel() #64
        X, Z = torch.meshgrid(x, z)


        s = (ze-zs)/(x[-1]-x[0])
        p = s*x + zs

        # Approximate the delta function over the path
        sigma = (x[1]-x[0])*2
        ray = torch.exp(-(X-x.unsqueeze(1))**2/sigma -(Z-p.unsqueeze(1))**2/sigma)
        ray[ray<0.1] = 0
        return ray

    def get_tomo_matrix(self, zs, ze, x, z):

        n = zs.numel() #65*65=4225

        A = torch.zeros(0, x.numel()*z.numel())
        A = A.to_sparse()
        nrays = tqdm.trange(n)

        for i in nrays:
            ray = self.get_ray(zs[i], ze[i], x, z)
            ray = ray.reshape(1, -1)
            ray = ray.to_sparse()
            A = torch.cat((A,ray),dim=0)
            nrays.set_description('Percent computed: {:2f}'.format(100*i/n))

        return A.to(device)

    def forward(self, u):
      return self.A@u.flatten().to(device)

    def adjoint(self, b):
      return self.A.t()@b.flatten().to(device)

# %%
x = torch.linspace(0, 63, 64)
z = torch.linspace(0, 127, 128)

t = torch.linspace(0, 127, 65)
zs, ze = torch.meshgrid(t, t)
zs = zs.flatten()
ze = ze.flatten()

tomo = tomography(zs, ze, x, z).to(device)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Percent computed: 99.976331: 100%|██████████| 4225/4225 [00:46<00:00, 91.38it/s]

# %%
x = np.arange(64)
z = np.arange(128)

model = gs.Gaussian(dim=2, var=0.9, len_scale=[9, 5], anis=0.9, angles=np.pi/8)
# model = gs.Exponential(dim=2, var=5, len_scale=[90, 25], angles=np.pi/4)
srf = gs.SRF(model, mean=0, seed = 100)

srf.structured([x,z])
# Transform
# values1 = np.linspace(np.min(srf.field), np.max(srf.field), 5)
# u = srf.transform("discrete", store="f1", values=srf.field)
#u = srf.transform("zinnharvey", conn="high")
u_noise = srf.field
# u = torch.tensor(u, dtype=torch.float32).to(device)
# utrue = u.clone().to(device)

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1,4,1)
plt.imshow(u_noise.reshape(64, 128).transpose(), origin = 'lower')
plt.axis('image')
plt.colorbar()
plt.title('true')
# Out:
# Text(0.5, 1.0, 'true')

# %%
utrue = np.ones([64, 128])
a = 20
center_l_i = 25
center_l_j = 44
center_r_i = 45
center_r_j = 74
for j in range(128):
  for i in range(64):
    r1 = ((i - center_l_i)**2 + (j-center_l_j)**2)**0.5
    r2 = ((i - center_r_i)**2 + (j-center_r_j)**2)**0.5
    if r1+r2<=2*a:
      utrue[i,j] = 8
utrue += u_noise
u = torch.tensor(utrue, dtype=torch.float32).to(device)
u[u < 0.3] = 0.3
utrue = u.clone().to(device)

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1,4,1)
plt.imshow(utrue.detach().cpu().reshape(64, 128).t(), origin = 'lower')
plt.axis('image')
plt.colorbar()

# %% [markdown]
# We can now use the forward model and the simulated model to generate some data we can try to invert

# %%
x = torch.linspace(0, 63, 64)
z = torch.linspace(0, 127, 128)

t = torch.linspace(0, 127, 65)
zs, ze = torch.meshgrid(t, t)
zs = zs.flatten()
ze = ze.flatten()

tomo = tomography(zs, ze, x, z).to(device)
# Out:
# Percent computed: 99.976331: 100%|██████████| 4225/4225 [00:17<00:00, 240.18it/s]

# %%
d = tomo(u).to(device)
# Add noise to the data
torch.manual_seed(0)
noise = torch.randn_like(d)
sig   = 20
dn = (d + sig*noise).to(device)

SNR = (dn-d).norm()/dn.norm()
print('Noise level = ', (SNR).item())
# Out:
# Noise level =  0.07214528322219849

# %%
class NFTOMO(nn.Module):
    def __init__(self):
         super(NFTOMO, self).__init__()
         self.b1 = nn.Sequential(nn.Linear(256,256), nn.LeakyReLU(inplace = True, negative_slope=0.2))
         self.b2 = nn.Sequential(nn.Linear(256,256), nn.LeakyReLU(inplace = True, negative_slope=0.2))
         self.b3 = nn.Sequential(nn.Linear(256,256), nn.LeakyReLU(inplace = True, negative_slope=0.2))
         self.b4 = nn.Sequential(nn.Linear(256,256), nn.LeakyReLU(inplace = True, negative_slope=0.2))
         self.b5 = nn.Sequential(nn.Linear(256,256), nn.LeakyReLU(inplace = True, negative_slope=0.2))
         self.b6 = nn.Sequential(nn.Linear(256,128), nn.LeakyReLU(inplace = True, negative_slope=0.2))
         self.b7 = nn.Sequential(nn.Linear(128,1), nn.Tanh())

    def forward(self, x):
        x1 = self.b1(x)

        x2 = self.b2(x1)

        x3 = self.b3(x2)

        x4 = self.b4(x3)

        x5 = self.b5(x4)

        x6 = self.b6(x5)

        x7 = self.b7(x6)


        return torch.mul(x7,10)

# %%
torch.manual_seed(0)
np.random.seed(0)
_model = NFTOMO().to(device)

# %%
x1 = np.linspace(-1,1,64)
x2 = np.linspace(-1,1,128)
input_list = []
for i in x1:
  for k in x2:
    input_list.append([i,k])
input_ = torch.tensor(input_list, dtype=torch.float32).to(device)

# %% [markdown]
# Gaussion Fourier encoding

# %%
def input_mapping(x, B):
  if B is None:
    return x
  else:
    x_proj = (np.pi*x) @ B.T
    return np.concatenate([np.sin(x_proj), np.cos(x_proj)], axis=-1)

# %%
np.random.seed(0)
mapping_size = 128
scale = .5#2.
B_gauss = np.random.normal(size = (mapping_size, 2))*scale

# %%
x= input_mapping(input_.detach().cpu(), B_gauss)

# %%
input_pos=torch.tensor(x, dtype=torch.float32).to(device)

# %%
output = _model(input_pos)

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1,4,1)
plt.imshow(utrue.detach().cpu().reshape(64, 128).t(),origin = 'lower')
plt.axis('image')
plt.colorbar()
plt.title('true')
plt.subplot(1,4,2)
plt.imshow(output.detach().cpu().reshape(64, 128).t(), origin = 'lower')
plt.axis('image')
cbar = plt.colorbar()
cbar.set_label('slowness (s/km)')
plt.title('inital NF output (Gaussion encoding scale .5)')
# Out:
# Text(0.5, 1.0, 'inital NF output (Gaussion encoding scale .5)')

# %%
# t_pos_=input_mapping(input_.detach().cpu(), np.eye(2))
input_pos=torch.tensor(x, dtype=torch.float32).to(device)

# %%
total_params = sum(p.numel() for p in _model.parameters())
print(f"Number of parameters: {total_params}")
# Out:
# Number of parameters: 361985

# %%
import torch.optim as optim
lr_ = 1e-3
# lr_ = 2e-3
optimizer = optim.Adam(_model.parameters(), lr=lr_)

# %%
def total_loss(output, Jtvec):
      """
          Note beta here differs from the beta in the convential EM inversion where beta typically starts with a value greater than 1 (e.x. 10), and then cooling down with a fixed rate.
          beta: [0,1]
          total_loss = (1-beta)*theta_phi + beta*theta_m
      """
      return (1/(output.size(dim=0)))*(Jtvec.t()@output)

# %%
# %matplotlib inline
from IPython import display

# %%
import pickle

# %%
fig = plt.figure(figsize=(5, 5), dpi= 80, facecolor='w', edgecolor='k')
axes = fig.subplots(1,2)
losses = []

for epoch in range(4500):
    output = _model(input_pos)
    #output = _model(input_pos) #CHANGE!!
    out_ = tomo.A@(output.detach())
    Jtvec = 2*tomo.A.t()@(out_-dn.unsqueeze(-1))
    loss = total_loss(output, Jtvec)
    optimizer.zero_grad()
    loss.backward()
    diff_ = ((out_-dn.unsqueeze(-1)).norm())**2
    losses.append(diff_.item())
    optimizer.step()
    if epoch%10 == 0:
      for ax in axes:
        ax.cla()
      axes[0].imshow(output.detach().cpu().reshape(64, 128).t(), origin = 'lower')
      axes[0].legend()
      axes[0].set_title('Recoverd model')
      axes[1].plot(losses, label='loss = ' + str(diff_))
      axes[1].set_yscale('log')
      axes[1].set_title('Training loss')
      axes[1].set_xlabel('number of gradient iterations')
      axes[1].legend()
      # print("The residual in the ", epoch, "is", ((out_-dn.unsqueeze(-1)).norm())**2)
      display.clear_output(wait=True)
      display.display(plt.gcf())
    if epoch%500 == 0:
      pkl_ = '7_layers_256_RELU_hete_Gaussion_encording'+'_'+str(epoch)
      pkl_name = pkl_+'.pkl'
      f = open(pkl_name, 'wb')
      pickle.dump(output, f)
      f.close()
plt.close('all')

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1,4,1)
plt.imshow(utrue.detach().cpu().reshape(64, 128).t(), origin = 'lower')
plt.axis('image')
plt.colorbar()
plt.title('true')
plt.subplot(1,4,2)
plt.imshow(output.detach().cpu().reshape(64, 128).t(), origin = 'lower', vmin = 0)
plt.axis('image')
cbar = plt.colorbar()
cbar.set_label('slowness (s/km)')
plt.title('Recovered')
# Out:
# Text(0.5, 1.0, 'Recovered')

# %%
import pickle
r_ = open('/content/7_layers_256_RELU_hete_Gaussion_encording_4500.pkl', 'wb')
pickle.dump(output, r_)
r_.close()

# %%
torch.save(_model, '7_layers_256_RELU_hete_Gaussion_encording_0.5.pt')
